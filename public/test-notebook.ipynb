# %% [markdown]
# # Python Kernel Test
#
# This notebook tests the on-demand Python kernel.

# %%
print('Hello from Pyodide!')

# %%
# Test numpy
import numpy as np
arr = np.array([1, 2, 3, 4, 5])
print(f'Array: {arr}')
print(f'Mean: {arr.mean()}')

# %%
# Test matplotlib
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

plt.figure(figsize=(8, 4))
plt.plot(x, y)
plt.title('Sine Wave')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.grid(True)
plt.show()

# %%
# Test error handling
print(undefined_variable)
